# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:/DS & ML/MLE/SoundSpeedEst/Train_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31043 entries, 0 to 31042
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LATITUDE     31043 non-null  float64
#  1   LONGITUDE    31043 non-null  float64
#  2   CTDPRS       31043 non-null  float64
#  3   CTDTMP       31043 non-null  float64
#  4   CTDSAL       31043 non-null  float64
#  5   depth_m      31043 non-null  float64
#  6   SA           31043 non-null  float64
#  7   CT           30798 non-null  float64
#  8   sound_speed  30798 non-null  float64
# dtypes: float64(9)
# memory usage: 2.1 MB

# %%
df = df.dropna()   # problem in gsw - conversion
df.head()
# Out:
#    LATITUDE  LONGITUDE  CTDPRS    CTDTMP     CTDSAL      depth_m         SA  \
# 0   -2.3390   141.1528  1122.5  6.899998  34.666039  1113.317028  34.839026
# 1   -2.2497   141.2340  1510.5  5.601913  34.660863  1496.766105  34.836505
# 2   -2.1690   141.4777  2106.0  4.411502  34.664981  2083.934239  34.842255
# 3   -2.0842   141.7432  1781.5  4.927637  34.661286  1764.176843  34.837729
# 4   -2.0038   141.9930  1820.5  4.915215  34.665020  1802.633308  34.841560
#
#          CT  sound_speed
# 0  6.785578  1496.123996
# 1  5.460302  1497.367556
# 2  4.225539  1502.399111
# 3  4.767019  1499.119218
# 4  4.750757  1499.720329

# %%
# pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#            LATITUDE     LONGITUDE        CTDPRS        CTDTMP        CTDSAL  \
# count  30798.000000  30798.000000  30798.000000  30798.000000  30798.000000
# mean      14.316374    -21.363195   1232.036165      5.282239     34.566004
# std       46.834957     91.875437    921.265897      5.644888      1.874971
# min      -78.637500   -179.988000      2.000000    -33.671929      0.005067
# 25%      -31.349975    -64.501000    374.000000      1.654424     34.448395
# 50%       30.864000    -41.046885   1021.000000      4.020230     34.666709
# 75%       49.434950     17.950200   2074.995898      7.355718     35.042618
# max       90.000000    191.383200   5252.500000     65.884272     39.675262
#
#             depth_m            SA            CT   sound_speed
# count  30798.000000  30798.000000  30798.000000  30798.000000
# mean    1216.956634     34.735513      5.172930   1489.852886
# std      908.679784      1.883452      5.648087     24.737858
# ...

# %%
sns.heatmap(df.corr(),annot=True)
plt.rcParams['figure.figsize'] = (8,8)
plt.show()

# %%
sns.barplot(df.groupby(by="LATITUDE").mean())
# Out:
# <Axes: >

# %%
df["LONGITUDE"].nunique(),df["LATITUDE"].nunique()
# Out:
# (24565, 24779)

# %%
nofvalue = int(input("no of values to plot = "))
sns.lineplot(x=df.LATITUDE.head(nofvalue),y=df.sound_speed.head(nofvalue))
# Out:
# <Axes: xlabel='LATITUDE', ylabel='sound_speed'>

# %%
# Outliers
df.boxplot(figsize=(16,9))
# Out:
# <Axes: >

# %%
# refer UImap.py for GeoPlot
