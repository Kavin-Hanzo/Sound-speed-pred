# %%
import pandas as pd
df = pd.read_csv("D:/DS & ML/MLE/SoundSpeedEst/Predicted_Speed.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30798 entries, 0 to 30797
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   LATITUDE               30798 non-null  float64
#  1   LONGITUDE              30798 non-null  float64
#  2   Actual_Sound_Speed     30798 non-null  float64
#  3   Predicted_Sound_Speed  30798 non-null  float64
# dtypes: float64(4)
# memory usage: 962.6 KB

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)
